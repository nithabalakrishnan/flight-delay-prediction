# %%
import pandas as pd

# %%
flights_cleaned = pd.read_csv("raw_data/flight_info_2018_cleaned.csv")

flights_cleaned.head()
# Out:
#    Unnamed: 0  ARR_DELAY  ARR_DELAY_NEW  ARR_TIME  DAY_OF_WEEK  DEP_DELAY  \
# 0           0       -1.0            0.0     417.0            1       -1.0
# 1           1      -32.0            0.0     933.0            1       -7.0
# 2           2        5.0            5.0     824.0            1       22.0
# 3           3        7.0            7.0    1436.0            1        2.0
# 4           4      212.0          212.0    2029.0            1      213.0
#
#    DEP_DELAY_NEW  DEP_TIME DEST  DEST_AIRPORT_ID DEST_CITY_NAME DEST_STATE_NM  \
# 0            0.0      54.0  DEN            11292     Denver, CO      Colorado
# 1            0.0     623.0  ORD            13930    Chicago, IL      Illinois
# 2           22.0     622.0  LAS            12889  Las Vegas, NV        Nevada
# 3            2.0     912.0  MEM            13244    Memphis, TN     Tennessee
# 4          213.0    1852.0  LAS            12889  Las Vegas, NV        Nevada
#
# ...

# %%
df = flights_cleaned.drop(['Unnamed: 0'], axis=1)
df.head()

len(df)
# Out:
# 7124914

# %%
tenPercent = df.sample(frac = 0.10)

len(tenPercent)

# tenPercent.to_csv("Flights10percent.csv")
# Out:
# 712491

# %%
origin_airports = tenPercent["ORIGIN"].unique()

# %%
len(origin_airports)
# Out:
# 357

# %%
airports = pd.DataFrame(origin_airports)

aiports

# %%
org_air = pd.read_csv("ORIGINairports.csv")
df2 = pd.read_csv("Flights10percent.csv")

org_air
# Out:
#         Airport Id  ORIGIN_AIRPORT_CODE  ORIGIN_LAT  ORIGIN_LONG
# 0           2566086                 BTI   70.134003  -143.582001
# 1           5985996                  \N   70.613403  -159.860001
# 2           1503516                 LUR   68.875099  -166.110001
# 3           4372872                 PIZ   69.732903  -163.005005
# 4           1302164                 ITO   19.721399  -155.048004
# 5           7117348                 ORL   28.545500   -81.332901
# 6           4037005                 BTT   66.913902  -151.529007
# 7           6749241                  \N   64.301201  -149.119995
# 8             90167                 UTO   65.992798  -153.703995
# 9           7027273                 FYU   66.571503  -145.250000
# 10          6672654                 SVW   61.097401  -155.574005
# 11          3631580                 FRN   61.266399  -149.653000
# 12          1456462                 TLJ   62.894402  -155.977005
# ...

# %%
result = pd.merge(df2, org_air, on ='ORIGIN_AIRPORT_CODE')



result
# Out:
#         Unnamed: 0  ARR_DELAY  ARR_DELAY_NEW  ARR_TIME  DAY_OF_WEEK  Latitude  \
# 0          2566086        -11              0      1312            3        -4
# 1          2394053        -15              0      1426            1        -4
# 2          6647146         18             18      1233            2        20
# 3          2465608         -3              0      2052            2        -5
# 4          1991725        -11              0      1434            3        -2
# 5           563693        -14              0      1424            7        -3
# 6          1260081        -11              0      1844            1         1
# 7          1872311        -10              0      1548            1        -4
# 8          3256643         -2              0      1913            5        -1
# 9          6542987        -12              0      1830            1         0
# 10         6350359          8              8       853            5        -3
# ...

# %%
DEST = pd.read_csv("destairports.csv")

DEST.head()
# Out:
#    Dest_Airport_Id  DEST_AIRPORT_CODE   DEST_LAT   DEST_LONG
# 0           2566086               BTI  70.134003 -143.582001
# 1           5985996                \N  70.613403 -159.860001
# 2           1503516               LUR  68.875099 -166.110001
# 3           4372872               PIZ  69.732903 -163.005005
# 4           1302164               ITO  19.721399 -155.048004

# %%
merged = pd.merge(DEST, result, on ='DEST_AIRPORT_CODE')

merged.head()
# Out:
#    Dest_Airport_Id  DEST_AIRPORT_CODE   DEST_LAT   DEST_LONG  Unnamed: 0  \
# 0           1302164               ITO  19.721399 -155.048004     3121452
# 1           1302164               ITO  19.721399 -155.048004     6412521
# 2           1302164               ITO  19.721399 -155.048004      435172
# 3           1302164               ITO  19.721399 -155.048004     5692916
# 4           1302164               ITO  19.721399 -155.048004     3369400
#
#    ARR_DELAY  ARR_DELAY_NEW  ARR_TIME  DAY_OF_WEEK  Latitude  ...     FL_DATE  \
# 0         -7              0      1931            3         0  ...  2018-07-25
# 1         -9              0      2027            6        15  ...  2018-10-27
# 2        -11              0      1934            6        -5  ...   4/14/2018
# 3        -31              0      2017            5       -14  ...  2018-11-30
# 4        -12              0      1938            6        -5  ...  2018-07-21
#
# ...

# %%
df = merged.drop(['Unnamed: 0', ], axis=1)
df.head()
# Out:
#    Dest_Airport_Id  DEST_AIRPORT_CODE   DEST_LAT   DEST_LONG  ARR_DELAY  \
# 0           1302164               ITO  19.721399 -155.048004         -7
# 1           1302164               ITO  19.721399 -155.048004         -9
# 2           1302164               ITO  19.721399 -155.048004        -11
# 3           1302164               ITO  19.721399 -155.048004        -31
# 4           1302164               ITO  19.721399 -155.048004        -12
#
#    ARR_DELAY_NEW  ARR_TIME  DAY_OF_WEEK  Latitude  DEP_DELAY_NEW  ...  \
# 0              0      1931            3         0              0  ...
# 1              0      2027            6        15             15  ...
# 2              0      1934            6        -5              0  ...
# 3              0      2017            5       -14              0  ...
# 4              0      1938            6        -5              0  ...
#
#       FL_DATE  OP_CARRIER_FL_NUM OP_UNIQUE_CARRIER ORIGIN_AIRPORT_CODE  \
# ...

# %%
new = [ 6 , 5,  7,  8,  9, 10, 11, 12, 15, 16, 17,  1,  2,  4,  0,  3, 13, 14]

# old1 = old.to_DataFrame

new1 = pd.DataFrame(new) 


new1 = new1.values.reshape(18, 1)

new1
# Out:
# array([[ 6],
#        [ 5],
#        [ 7],
#        [ 8],
#        [ 9],
#        [10],
#        [11],
#        [12],
#        [15],
#        [16],
#        [17],
#        [ 1],
#        [ 2],
#        [ 4],
#        [ 0],
#        [ 3],
#        [13],
#        [14]], dtype=int64)

# %%
df.to_csv("Flight_data_coords.csv")

# %%
old = ['F9', 'EV', 'G4', 'HA', 'MQ', 'NK', 'OH' ,'OO', 'WN', 'YV', 'YX' ,'AA', 'AS' ,'DL',
 '9E', 'B6', 'UA', 'VX']

old1 = pd.DataFrame(old) 

old1 = old1.values.reshape(18, 1)

old1
# Out:
# array([['F9'],
#        ['EV'],
#        ['G4'],
#        ['HA'],
#        ['MQ'],
#        ['NK'],
#        ['OH'],
#        ['OO'],
#        ['WN'],
#        ['YV'],
#        ['YX'],
#        ['AA'],
#        ['AS'],
#        ['DL'],
#        ['9E'],
#        ['B6'],
#        ['UA'],
#        ['VX']], dtype=object)
