# %%
# Dependencies
import pandas as pd
import glob

# %%
# Merging csv files (without repeating header)
interesting_files = glob.glob("RawData/*.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in interesting_files))
df
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#         ARR_DELAY  ARR_DELAY_NEW  ARR_TIME  CARRIER_DELAY  DAY_OF_WEEK  \
# 0           -17.0            0.0    1521.0            NaN            1
# 1             1.0            1.0    1535.0            NaN            1
# 2           -12.0            0.0    1522.0            NaN            1
# 3            13.0           13.0    1547.0            NaN            1
# 4             1.0            1.0    1535.0            NaN            1
# 5             5.0            5.0    1828.0            NaN            1
# ...

# %%
df.count()
# Out:
# ARR_DELAY              7130071
# ARR_DELAY_NEW          7130071
# ARR_TIME               7148852
# CARRIER_DELAY          1400632
# DAY_OF_WEEK            7272370
# DEP_DELAY              7150656
# DEP_DELAY_NEW          7150656
# DEP_TIME               7156199
# DEST                   7272370
# DEST_AIRPORT_ID        7272370
# DEST_CITY_NAME         7272370
# DEST_STATE_NM          7272370
# FL_DATE                7272370
# LATE_AIRCRAFT_DELAY    1400632
# NAS_DELAY              1400632
# OP_CARRIER_FL_NUM      7272370
# OP_UNIQUE_CARRIER      7272370
# ORIGIN                 7272370
# ORIGIN_AIRPORT_ID      7272370
# ORIGIN_CITY_NAME       7272370
# ORIGIN_STATE_NM        7272370
# SECURITY_DELAY         1400632
# Unnamed: 23                  0
# WEATHER_DELAY          1400632
# dtype: int64

# %%
# Export file as a CSV
df.to_csv("CleanData/Flight_info_2018.csv")

# %%
len(df)

# %%
df_data = pd.read_csv("CleanData/Flight_info_2018.csv")

# %%
len(df_data)
